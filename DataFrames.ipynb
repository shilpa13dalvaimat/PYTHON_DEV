# %%
import pandas as pd

# %%
student_records={
    "Rollno":[1,2,3,4,5],
     "Name":['Rohit','Rohan','Sam','Shakti','Ram'],
    "Subject":['Java','Python','c++','python','Ruby'],
     "Marks":[90,95,40,60,75]
}
# This is a dictonary with multiple lists

# %%
pd.Dataframe(student_records)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-48d4bc89ad28> in <module>
# ----> 1 pd.Dataframe(student_records)
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
df=pd.DataFrame(student_records)
df
# Out:
#    Rollno    Name Subject  Marks
# 0       1   Rohit    Java     90
# 1       2   Rohan  Python     95
# 2       3     Sam     c++     40
# 3       4  Shakti  python     60
# 4       5     Ram    Ruby     75

# %%
df.dtype()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-144c7b0decef> in <module>
# ----> 1 df.dtype()
#
# ~\Downloads\Programs\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
df.dtypes
# Out:
# Rollno      int64
# Name       object
# Subject    object
# Marks       int64
# dtype: object

# %%
df.shape
# Out:
# (5, 4)

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 20

# %%
df["marks"].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Downloads\Programs\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'marks'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-9366bfbef09a> in <module>
# ----> 1 df["marks"].max()
#
# ...

# %%
df["Marks"].max()
# Out:
# 95

# %%
df["Marks"].min()
# Out:
# 40

# %%
df["Name"][df["Marks"]==df["Marks"].max()]
# Out:
# 1    Rohan
# Name: Name, dtype: object

# %%
df["Name"]df["Marks"]df["Rollno"]df[["Subject"]==df["Marks"].max()]
# Out:
#   File "<ipython-input-17-635ee4e1f750>", line 1
#     df["Name"]df["Marks"]df["Rollno"]df[["Subject"]==df["Marks"].max()]
#                ^
# SyntaxError: invalid syntax

# %%
df[["Name","Subject","Rollno"]][df["Marks"]==df["Marks"].max()]
# Out:
#     Name Subject  Rollno
# 1  Rohan  Python       2

# %%
df[][df["Marks"]==df["Marks"].max()]
# Out:
#   File "<ipython-input-19-71b7e4765500>", line 1
#     df[][df["Marks"]==df["Marks"].max()]
#        ^
# SyntaxError: invalid syntax

# %%
df[df["Marks"]==df["Marks"].max()]
# Out:
#    Rollno   Name Subject  Marks
# 1       2  Rohan  Python     95

# %%
df[][df["Marks"]==df["subject"]=('python')]
# Out:
#   File "<ipython-input-22-d73206214827>", line 1
#     df[][df["Marks"]==df["subject"]=('python')]
#        ^
# SyntaxError: invalid syntax

# %%
df["Name"][df["Marks"]==df["Marks"]]
# Out:
# 0     Rohit
# 1     Rohan
# 2       Sam
# 3    Shakti
# 4       Ram
# Name: Name, dtype: object

# %%
df["Marks"].mean()
# Out:
# 72.0

# %%
df.marks
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-ed005dff80aa> in <module>
# ----> 1 df.marks
#
# ~\Downloads\Programs\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'marks'

# %%
df.Marks
# Out:
# 0    90
# 1    95
# 2    40
# 3    60
# 4    75
# Name: Marks, dtype: int64

# %%
df["Name"][df["Marks"]==df.Marks
# Out:
#   File "<ipython-input-29-1d3ab4ad813d>", line 1
#     df["Name"][df["Marks"]==df.Marks
#                                     ^
# SyntaxError: unexpected EOF while parsing

# %%
df.Marks.std()
# Out:
# 22.52776065213762

# %%
import numpy as np

# %%
numArr=np.loadtxt(fname="C:\Shilpa\winequality-red.csv",delimiter='',skiprows=1)
numArr
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-766d21bf3a59> in <module>
# ----> 1 numArr=np.loadtxt(fname="C:\Shilpa\winequality-red.csv",delimiter='',skiprows=1)
#       2 numArr
#
# ~\Downloads\Programs\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#    1085             while not first_vals:
#    1086                 first_line = next(fh)
# -> 1087                 first_vals = split_line(first_line)
#    1088         except StopIteration:
#    1089             # End of lines reached
#
# ~\Downloads\Programs\lib\site-packages\numpy\lib\npyio.py in split_line(line)
#    1028         line = line.strip('\r\n')
#    1029         if line:
# -> 1030             return line.split(delimiter)
#    1031         else:
#    1032             return []
#
# ...

# %%
import pandas as pd

# %%
numArr=np.read_csv(fname="C:\Shilpa\winequality-red.csv",delimiter='',skiprows=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-7d6ff1c82823> in <module>
# ----> 1 numArr=np.read_csv(fname="C:\Shilpa\winequality-red.csv",delimiter='',skiprows=1)
#
# AttributeError: module 'numpy' has no attribute 'read_csv'

# %%
numArr
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %%
type(numArr)
# Out:
# pandas.core.frame.DataFrame

# %%
ndim(numArr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-7852a6d516b0> in <module>
# ----> 1 ndim(numArr)
#
# NameError: name 'ndim' is not defined

# %%
numArr.shape
# Out:
# (1599, 12)

# %%
numArr.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
numArr.ndim
# Out:
# 2

# %%
numArr=pd.read_excel("C:\Shilpa\Min_Max_Seasonal.xls")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-45-2ebf5d9417aa> in <module>
# ----> 1 numArr=pd.read_excel("C:\Shilpa\Min_Max_Seasonal.xls")
#
# ~\Downloads\Programs\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ~\Downloads\Programs\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ...

# %%
numArr=pd.read_excel("C:\Shilpa\Min_Max_Seasonal.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-46-26d77eee3d50> in <module>
# ----> 1 numArr=pd.read_excel("C:\Shilpa\Min_Max_Seasonal.xlsx")
#
# ~\Downloads\Programs\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ~\Downloads\Programs\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ...

# %%
numArr=pd.read_csv("C:\Shilpa\winequality-red.csv")

# %%
numArr
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %%
numArr=pd.read_excel("C:\Shilpa\Min_Max_Seasonal.xlsx")

# %%
numArr
# Out:
#     YEAR  ANNUAL - MIN  ANNUAL - MAX  JAN-FEB - MIN  JAN-FEB - MAX  \
# 0   2000         19.48         29.75          13.84          24.82
# 1   2001         19.49         29.99          13.60          25.88
# 2   2002         19.78         30.23          13.93          25.37
# 3   2003         19.70         29.75          14.32          25.32
# 4   2004         19.69         29.79          14.39          25.47
# 5   2005         19.58         29.60          14.63          24.96
# 6   2006         20.07         30.06          15.47          27.44
# 7   2007         19.69         29.84          14.47          25.73
# 8   2008         19.60         29.64          13.60          24.72
# 9   2009         19.94         30.30          14.95          26.51
# 10  2010         20.15         30.13          14.51          25.96
# 11  2011         19.58         29.82          13.84          25.33
# 12  2012         19.54         29.81          13.68          25.03
# ...

# %%
student_record=[
    {'Name':'Rohit', 'Rollno':1},
    {'Name':'Ram','Rollno':2}
]

# %%
student_record=[(1,'Rohit'),(2,'Ram')]
df.DataFrame(student_record,Columns={"Rollno","Name"})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-cf11c177098f> in <module>
#       1 student_record=[(1,'Rohit'),(2,'Ram')]
# ----> 2 df.DataFrame(student_record,Columns={"Rollno","Name"})
#
# ~\Downloads\Programs\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'DataFrame'

# %%
student_record=[(1,'Rohit'),(2,'Ram')]
pd.DataFrame(student_record,columns={"Rollno","Name"})
# Out:
#    Name Rollno
# 0     1  Rohit
# 1     2    Ram

# %%
#Above are the different types of reading a data frames.

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\admin\Downloads\anaconda\D1.csv",sep='|', header=0)

# %%
df
# Out:
#   D,ABC Inc,India,100
# 0   D,XYZ Inc,USA,250
# 1     D,ASD Inc,UK,50

# %%
df=pd.read_csv(r"C:\Users\admin\Downloads\anaconda\D2.csv")

# %%
df
# Out:
# Empty DataFrame
# Columns: [T, 3, 400]
# Index: []

# %%
df=pd.read_csv(r"D:\OlympicAthletes.csv")

# %%
df
# Out:
#                         Athlete        Country  Year  \
# 0                    Yang Yilin          China  2008
# 1                  Leisel Jones      Australia  2000
# 2                   Go Gi-Hyeon    South Korea  2002
# 3                   Chen Ruolin          China  2008
# 4                 Katie Ledecky  United States  2012
# 5                Ruta Meilutyte      Lithuania  2012
# 6                 Dániel Gyurta        Hungary  2004
# 7               Arianna Fontana          Italy  2006
# 8                Olga Glatskikh         Russia  2004
# 9            Kharikleia Pantazi         Greece  2000
# 10                   Kim Martin         Sweden  2002
# 11                    Kyla Ross  United States  2012
# 12              Gabriela Dragoi        Romania  2008
# 13       Tasha Schwikert-Warren  United States  2000
# 14                     Yang Yun          China  2000
# 15                 Sophie Lamon    Switzerland  2000
# 16             Alejandra Orozco         Mexico  2012
# ...

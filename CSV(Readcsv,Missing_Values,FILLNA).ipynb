# %%
import pandas as pd
numArr=pd.read_csv(r"C:\Shilpa\train.csv",nrows=10)

# %%
numArr
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
numArr['Name'][numArr['Survived']==0]
# Out:
# 0                                Braund, Mr. Owen Harris
# 4                               Allen, Mr. William Henry
# 5                                       Moran, Mr. James
# 6                                McCarthy, Mr. Timothy J
# 7                         Palsson, Master. Gosta Leonard
# 12                        Saundercock, Mr. William Henry
# 13                           Andersson, Mr. Anders Johan
# 14                  Vestrom, Miss. Hulda Amanda Adolfina
# 16                                  Rice, Master. Eugene
# 18     Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 20                                  Fynney, Mr. Joseph J
# 24                         Palsson, Miss. Torborg Danira
# 26                               Emir, Mr. Farred Chehab
# 27                        Fortune, Mr. Charles Alexander
# 29                                   Todoroff, Mr. Lalio
# 30                              Uruchurtu, Don. Manuel E
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-28f4ae6ebd8e> in <module>
# ----> 1 df('Name',nrow=10)
#
# NameError: name 'df' is not defined

# %%
numArr=pd.read_csv(r"C:\Shilpa\train.csv",skiprows=10)
numArr
# Out:
#       10  1  2                Nasser, Mrs. Nicholas (Adele Achem)  female  \
# 0     11  1  3                    Sandstrom, Miss. Marguerite Rut  female
# 1     12  1  1                           Bonnell, Miss. Elizabeth  female
# 2     13  0  3                     Saundercock, Mr. William Henry    male
# 3     14  0  3                        Andersson, Mr. Anders Johan    male
# 4     15  0  3               Vestrom, Miss. Hulda Amanda Adolfina  female
# 5     16  1  2                   Hewlett, Mrs. (Mary D Kingcome)   female
# 6     17  0  3                               Rice, Master. Eugene    male
# 7     18  1  2                       Williams, Mr. Charles Eugene    male
# 8     19  0  3  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female
# 9     20  1  3                            Masselmani, Mrs. Fatima  female
# 10    21  0  2                               Fynney, Mr. Joseph J    male
# 11    22  1  2                              Beesley, Mr. Lawrence    male
# ...

# %%
numArr=pd.read_csv(r"C:\Shilpa\train.csv",header=1)
numArr
# Out:
#        1  0  3                            Braund, Mr. Owen Harris    male  \
# 0      2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 1      3  1  3                             Heikkinen, Miss. Laina  female
# 2      4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 3      5  0  3                           Allen, Mr. William Henry    male
# 4      6  0  3                                   Moran, Mr. James    male
# 5      7  0  1                            McCarthy, Mr. Timothy J    male
# 6      8  0  3                     Palsson, Master. Gosta Leonard    male
# 7      9  1  3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 8     10  1  2                Nasser, Mrs. Nicholas (Adele Achem)  female
# 9     11  1  3                    Sandstrom, Miss. Marguerite Rut  female
# 10    12  1  1                           Bonnell, Miss. Elizabeth  female
# 11    13  0  3                     Saundercock, Mr. William Henry    male
# ...

# %%
numArr=pd.read_csv(r"C:\Shilpa\train.csv",header=None)
numArr
# Out:
#               0         1       2   \
# 0    PassengerId  Survived  Pclass
# 1              1         0       3
# 2              2         1       1
# 3              3         1       3
# 4              4         1       1
# 5              5         0       3
# 6              6         0       3
# 7              7         0       1
# 8              8         0       3
# 9              9         1       3
# 10            10         1       2
# 11            11         1       3
# 12            12         1       1
# 13            13         0       3
# 14            14         0       3
# 15            15         0       3
# 16            16         1       2
# 17            17         0       3
# 18            18         1       2
# 19            19         0       3
# 20            20         1       3
# 21            21         0       2
# 22            22         1       2
# 23            23         1       3
# 24            24         1       1
# ...

# %%
numArr=pd.read_csv(r"C:\Shilpa\train1.csv",header=None, names=['PassengerID','Survivedppl'])
numArr
# Out:
#                                                                                                       PassengerID  \
# 1   0 3 Braund, Mr. Owen Harris                            male   22.0 1 0 A/5 21171        7.2500            NaN
# 2   1 1 Cumings, Mrs. John Bradley (Florence Briggs Tha... female 38.0 1 0 PC 17599         71.2833           C85
# 3   1 3 Heikkinen, Miss. Laina                             female 26.0 0 0 STON/O2. 3101282 7.9250            NaN
# 4   1 1 Futrelle, Mrs. Jacques Heath (Lily May Peel)       female 35.0 1 0 113803           53.1000          C123
# 5   0 3 Allen, Mr. William Henry                           male   35.0 0 0 373450           8.0500            NaN
# 6   0 3 Moran, Mr. James                                   male   NaN  0 0 330877           8.4583            NaN
# 7   0 1 McCarthy, Mr. Timothy J                            male   54.0 0 0 17463            51.8625           E46
# ...

# %%
df=pd.read_csv(r"C:\Shilpa\train.csv",nrows=10)
df.to_csv(r"C:\Shilpa\NewFile.csv",header=false)

# %%
df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df=pd.read_csv(r"C:\Shilpa\train.csv",nrows=10)
df.to_csv(r"C:\Shilpa\NewFile.csv",header=False)

# %%
df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df=pd.read_csv(r"C:\Shilpa\train.csv",nrows=10)
df.to_csv(r"C:\Shilpa\NewFile.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-47-98523ce7bee0> in <module>
#       1 df=pd.read_csv(r"C:\Shilpa\train.csv",nrows=10)
# ----> 2 df.to_csv(r"C:\Shilpa\NewFile.csv",index=False)
#
# ~\Downloads\Programs\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# ~\Downloads\Programs\lib\site-packages\pandas\io\formats\csvs.py in save(self)
# ...

# %%
df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df=pd.read_csv(r"C:\Shilpa\train.csv",nrows=10)
df.to_csv(r"C:\Shilpa\NewFile.csv",index=False)
df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df=pd.read_csv(r"C:\Shilpa\train.csv",nrows=10)
df.to_csv(r"C:\Shilpa\NewFile.csv")
df[(df['Age']>30)&(df['Survived']==0)]
# Out:
#    PassengerId  Survived  Pclass                      Name   Sex   Age  SibSp  \
# 4            5         0       3  Allen, Mr. William Henry  male  35.0      0
# 6            7         0       1   McCarthy, Mr. Timothy J  male  54.0      0
#
#    Parch  Ticket     Fare Cabin Embarked
# 4      0  373450   8.0500   NaN        S
# 6      0   17463  51.8625   E46        S

# %%
df[(df['Age']>30)&(df['Survived']==0)]
# Out:
#    PassengerId  Survived  Pclass                      Name   Sex   Age  SibSp  \
# 4            5         0       3  Allen, Mr. William Henry  male  35.0      0
# 6            7         0       1   McCarthy, Mr. Timothy J  male  54.0      0
#
#    Parch  Ticket     Fare Cabin Embarked
# 4      0  373450   8.0500   NaN        S
# 6      0   17463  51.8625   E46        S

# %%
res=df[(df['Age']>30)&(df['Survived']==0)]
res
# Out:
#    PassengerId  Survived  Pclass                      Name   Sex   Age  SibSp  \
# 4            5         0       3  Allen, Mr. William Henry  male  35.0      0
# 6            7         0       1   McCarthy, Mr. Timothy J  male  54.0      0
#
#    Parch  Ticket     Fare Cabin Embarked
# 4      0  373450   8.0500   NaN        S
# 6      0   17463  51.8625   E46        S

# %%
res.to_csv(r"C:\Shilpa\NewFile1.csv", columns=["Name", "Age"],index=False)

# %%
df=pd.read_csv(r"C:\Shilpa\train.csv")
result=df.groupby('Name')
result

# %%
for(i,j in result):
# Out:
#   File "<ipython-input-69-d57a82adb0bd>", line 1
#     for(i,j in result):
#                       ^
# SyntaxError: invalid syntax

# %%
for i,j in result:
    print (i)
    print (j)
# Out:
# Abbing, Mr. Anthony
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 845          846         0       3  Abbing, Mr. Anthony  male  42.0      0
#
#      Parch     Ticket  Fare Cabin Embarked
# 845      0  C.A. 5547  7.55   NaN        S
# Abbott, Mr. Rossmore Edward
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 746          747         0       3  Abbott, Mr. Rossmore Edward  male  16.0
#
#      SibSp  Parch     Ticket   Fare Cabin Embarked
# 746      1      1  C.A. 2673  20.25   NaN        S
# Abbott, Mrs. Stanton (Rosa Hunt)
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 279          280         1       3  Abbott, Mrs. Stanton (Rosa Hunt)  female
#
#       Age  SibSp  Parch     Ticket   Fare Cabin Embarked
# 279  35.0      1      1  C.A. 2673  20.25   NaN        S
# Abelson, Mr. Samuel
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# ...

# %%
import pandas as pd

student_records={
    "Rollno":[1,2,3,4],
     "Name":['Rohit','Rohan','Sam','Shakti'],
    "Department":['D1','T1','D2','T1'],
     "Marks":[90,95,40,60]
}
# This is a dictonary with multiple lists

# %%
df=pd.DataFrame(student_records)
df
# Out:
#    Rollno    Name Department  Marks
# 0       1   Rohit         D1     90
# 1       2   Rohan         T1     95
# 2       3     Sam         D2     40
# 3       4  Shakti         T1     60

# %%
df
# Out:
#    Rollno    Name Department  Marks
# 0       1   Rohit         D1     90
# 1       2   Rohan         T1     95
# 2       3     Sam         D2     40
# 3       4  Shakti         T2     60

# %%
X=df.groupby('Department')
X.get_group('T1')
# Out:
#    Rollno    Name Department  Marks
# 1       2   Rohan         T1     95
# 3       4  Shakti         T1     60

# %%
df=pd.read_csv(r"C:\Shilpa\Train_MissValcsv.csv")

df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male    22
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female    38
# 2                             Heikkinen, Miss. Laina  female    26
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    35
# 4                           Allen, Mr. William Henry    male    35
# 5                                   Moran, Mr. James    male  n.a.
# 6                            McCarthy, Mr. Timothy J    male    54
# 7                     Palsson, Master. Gosta Leonard    male     2
#
# ...

# %%
df.fillna(0)F
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male    22
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female    38
# 2                             Heikkinen, Miss. Laina  female    26
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    35
# 4                           Allen, Mr. William Henry    male    35
# 5                                   Moran, Mr. James    male  n.a.
# 6                            McCarthy, Mr. Timothy J    male    54
# 7                     Palsson, Master. Gosta Leonard    male     2
#
# ...

# %%
df.fillna({DOB:'Not Available'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-110-e5a2df988515> in <module>
# ----> 1 df.fillna({DOB:'Not Available'})
#
# NameError: name 'DOB' is not defined

# %%
df.fillna(method='FFill')
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male    22
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female    38
# 2                             Heikkinen, Miss. Laina  female    26
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    35
# 4                           Allen, Mr. William Henry    male    35
# 5                                   Moran, Mr. James    male  n.a.
# 6                            McCarthy, Mr. Timothy J    male    54
# 7                     Palsson, Master. Gosta Leonard    male     2
#
# ...

# %%
df.fillna(method='BFill')
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male    22
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female    38
# 2                             Heikkinen, Miss. Laina  female    26
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    35
# 4                           Allen, Mr. William Henry    male    35
# 5                                   Moran, Mr. James    male  n.a.
# 6                            McCarthy, Mr. Timothy J    male    54
# 7                     Palsson, Master. Gosta Leonard    male     2
#
# ...

# %%
df.fillna(method='FFill',limit=1)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male    22
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female    38
# 2                             Heikkinen, Miss. Laina  female    26
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    35
# 4                           Allen, Mr. William Henry    male    35
# 5                                   Moran, Mr. James    male  n.a.
# 6                            McCarthy, Mr. Timothy J    male    54
# 7                     Palsson, Master. Gosta Leonard    male     2
#
# ...

# %%
df=pd.read_csv(r"C:\Shilpa\Train_MissValcsv.csv")

df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male    22
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female    38
# 2                             Heikkinen, Miss. Laina  female    26
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    35
# 4                           Allen, Mr. William Henry    male    35
# 5                                   Moran, Mr. James    male  n.a.
# 6                            McCarthy, Mr. Timothy J    male    54
# 7                     Palsson, Master. Gosta Leonard    male     2
#
# ...

# %%
df.fillna(method='FFill',limit=2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male    22
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female    38
# 2                             Heikkinen, Miss. Laina  female    26
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    35
# 4                           Allen, Mr. William Henry    male    35
# 5                                   Moran, Mr. James    male  n.a.
# 6                            McCarthy, Mr. Timothy J    male    54
# 7                     Palsson, Master. Gosta Leonard    male     2
#
# ...
